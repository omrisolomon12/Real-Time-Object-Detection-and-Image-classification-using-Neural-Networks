# %%
import os
path = os.chdir("C:/Users/97250/Desktop/CognataCamera_ann/CognataCamera_ann")

#for file in glob.glob(path):
#    a=open(file)
#    my_list.append(a)
#l=len(my_list)
#print(l)
i = 0
for file in os.listdir(path):
    print(file)
    new_file_name = "frame{}.csv".format(i)
    os.rename(file,new_file_name)
    print(new_file_name)
    i=i+1
# Out:
# 0000000033.csv
# frame0.csv
# 0000000066.csv
# frame1.csv
# 0000000100.csv
# frame2.csv
# 0000000133.csv
# frame3.csv
# 0000000166.csv
# frame4.csv
# 0000000200.csv
# frame5.csv
# 0000000233.csv
# frame6.csv
# 0000000266.csv
# frame7.csv
# 0000000300.csv
# frame8.csv
# 0000000333.csv
# frame9.csv
# 0000000366.csv
# frame10.csv
# 0000000400.csv
# frame11.csv
# 0000000433.csv
# frame12.csv
# 0000000466.csv
# frame13.csv
# 0000000500.csv
# frame14.csv
# 0000000533.csv
# frame15.csv
# 0000000566.csv
# frame16.csv
# 0000000600.csv
# frame17.csv
# 0000000633.csv
# frame18.csv
# 0000000666.csv
# frame19.csv
# 0000000699.csv
# frame20.csv
# 0000000733.csv
# frame21.csv
# 0000000766.csv
# frame22.csv
# 0000000800.csv
# frame23.csv
# 0000000833.csv
# frame24.csv
# 0000000866.csv
# frame25.csv
# 0000000899.csv
# frame26.csv
# 0000000933.csv
# frame27.csv
# 0000000966.csv
# frame28.csv
# 0000001000.csv
# frame29.csv
# 0000001033.csv
# frame30.csv
# 0000001066.csv
# frame31.csv
# 0000001100.csv
# ...
